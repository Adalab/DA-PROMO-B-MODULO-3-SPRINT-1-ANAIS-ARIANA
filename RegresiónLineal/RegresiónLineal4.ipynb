# %%
import pandas as pd
import random 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

import researchpy as rp
import scipy.stats as stats
from scipy.stats import levene
from scipy.stats import kstest
from scipy.stats import skew


plt.rcParams["figure.figsize"] = (16,10) 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### <font color=green>En este ejercicio de pair programming seguiréis usando el dataset que seleccionasteis.

# %%
df = pd.read_pickle("datos/cars_price1.pkl")
df.head(2)
# Out:
#      Price    Levy Manufacturer    Model  Prod. year Category  \
# 0  13328.0  1399.0        LEXUS   RX 450        2010     Jeep
# 1  16621.0  1018.0    CHEVROLET  Equinox        2011     Jeep
#
#   Leather interior Fuel type Engine volume   Mileage  Cylinders Gear box type  \
# 0              Yes    Hybrid           3.5  186005.0        6.0     Automatic
# 1               No    Petrol             3  192000.0        6.0     Tiptronic
#
#   Drive wheels Doors   Color  Airbags
# 0          4x4    04  Silver       12
# 1          4x4    04   Black        8

# %% [markdown]
# ##### <font color=green> El objetivo de este pair programming es que evaluéis si vuestro set de datos cumple todas las asunciones que se deben cumplir para hacer una regresión lineal. Recordamos que estas asunciones son:

# %% [markdown]
# ### <font color=violet>  Normalidad

# %% [markdown]
# - Test de normalidad visualmente

# %%
sns.histplot(df['Price'], kde = True, bins = 20);

# %% [markdown]
# Visualmente podemos observar que no tenemos una distribución normal en nuestra variable respuesta, ya que la gráfica no se parece a una campana de gauss.

# %% [markdown]
# - Test de Normalidad Analíticamente

# %%
kstest(df['Price'], 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# Analíticamente el kstest nos demuestra que nuestro *p-valor* < 0.05, podemos rechazar la H0 por lo que los datos no  son normales.

# %% [markdown]
# ### <font color=violet> Homogeneidad de varianzas

# %% [markdown]
# Realizamos boxplot por cada una de nuestras variables categóricas:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13584 entries, 0 to 19234
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             13584 non-null  float64
#  1   Levy              13584 non-null  float64
#  2   Manufacturer      13584 non-null  object
#  3   Model             13584 non-null  object
#  4   Prod. year        13584 non-null  int64
#  5   Category          13584 non-null  object
#  6   Leather interior  13584 non-null  object
#  7   Fuel type         13584 non-null  object
#  8   Engine volume     13584 non-null  object
#  9   Mileage           13584 non-null  float64
#  10  Cylinders         13584 non-null  float64
#  11  Gear box type     13584 non-null  object
#  12  Drive wheels      13584 non-null  object
#  13  Doors             13584 non-null  category
#  14  Color             13584 non-null  object
#  15  Airbags           13584 non-null  int64
# dtypes: category(1), float64(4), int64(2), object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# Manufacturer:

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Manufacturer',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por fabricante')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Fabricante del coche')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 80);

# %%
df["Manufacturer"].unique()
# Out:
# array(['LEXUS', 'CHEVROLET', 'HONDA', 'FORD', 'HYUNDAI', 'TOYOTA',
#        'MERCEDES-BENZ', 'PORSCHE', 'JEEP', 'VOLKSWAGEN', 'AUDI',
#        'RENAULT', 'NISSAN', 'SUBARU', 'DAEWOO', 'BMW', 'KIA',
#        'MITSUBISHI', 'SSANGYONG', 'MAZDA', 'GMC', 'FIAT', 'INFINITI',
#        'ALFA ROMEO', 'SUZUKI', 'OPEL', 'LINCOLN', 'CITROEN', 'MINI',
#        'DODGE', 'CHRYSLER', 'JAGUAR', 'LAND ROVER', 'ACURA', 'VAZ',
#        'SKODA', 'DAIHATSU', 'BUICK', 'TESLA', 'CADILLAC', 'PEUGEOT',
#        'BENTLEY', 'VOLVO', 'სხვა', 'HAVAL', 'HUMMER', 'SCION', 'MERCURY',
#        'SEAT', 'LANCIA', 'FERRARI', 'MASERATI', 'SAAB', 'GAZ', 'PONTIAC',
#        'SATURN', 'ASTON MARTIN', 'GREATWALL'], dtype=object)

# %%
lexus = df[df["Manufacturer"] == 'LEXUS']["Price"]
chevrolet = df[df["Manufacturer"] == 'CHEVROLET']["Price"]
honda = df[df["Manufacturer"] == 'HONDA']["Price"]
ford = df[df["Manufacturer"] == 'FORD']["Price"]

# %%
# Levene test
# ==============================================================================
levene_test = stats.levene(lexus, chevrolet, honda, ford, center='median')
levene_test
# Out:
# LeveneResult(statistic=35.30885787792999, pvalue=2.131559575580672e-22)

# %% [markdown]
# Modelo

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Model',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por categoría')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Categoría del coche')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 80);

# %% [markdown]
# Cómo podemos ver, esta gráfica no nos da la infromación que necesitamos, cómo los modelos se encuentran denro de las categorias de fabricantes, hemos decicidido eliminar los modelos y quedarnos sólo con los fabricantes.

# %%
df.shape
# Out:
# (13584, 16)

# %%
df.drop(['Model'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      Price    Levy Manufacturer  Prod. year   Category Leather interior  \
# 0  13328.0  1399.0        LEXUS        2010       Jeep              Yes
# 1  16621.0  1018.0    CHEVROLET        2011       Jeep               No
# 2   8467.0     0.0        HONDA        2006  Hatchback               No
# 3   3607.0   862.0         FORD        2011       Jeep              Yes
# 4  11726.0   446.0        HONDA        2014  Hatchback              Yes
#
#   Fuel type Engine volume   Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005.0        6.0     Automatic          4x4
# 1    Petrol             3  192000.0        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000.0        4.0      Variator        Front
# 3    Hybrid           2.5  168966.0        4.0     Automatic          4x4
# 4    Petrol           1.3   91901.0        4.0     Automatic        Front
#
#   Doors   Color  Airbags
# 0    04  Silver       12
# 1    04   Black        8
# 2    04   Black        2
# 3    04   White        0
# 4    04  Silver        4

# %% [markdown]
# Categoría

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Category',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por categoría')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Categoría del coche')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 50);

# %% [markdown]
# Cuero interior

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Leather interior',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por cuero en el interior del coche')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Cuero en el interior del coche');

# %% [markdown]
# Tipo de carburante

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Fuel type',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por tipo de carburante')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Tipo de carburante');

# %% [markdown]
# Cilindrada

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Engine volume',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por cilindrada')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Cilindrada')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90);

# %% [markdown]
# Caja de cambios

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Gear box type',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por tipo de caja de cambios')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Caja de cambios');

# %% [markdown]
# Tracción de las ruedas:

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Drive wheels',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por tracción de las ruedas')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Tracción de las ruedas');

# %% [markdown]
# Número de puertas:

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Doors',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por cantidad de puertas')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Número de puertas');

# %% [markdown]
# Color:

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

sns.boxplot(
    x       = 'Color',
    y       = 'Price',
    data    = df,
    palette = 'tab10',
    ax      = ax
)
ax.set_title('Distribución de precios por color')
ax.set_ylabel('Precio del coche')
ax.set_xlabel('Color');

# %% [markdown]
# Luego de visualizar los boxplot para cada variable podemos decir que nuestras variables no son homogéneas porque las varianzas son muy desiguales en cada gráfica.

# %%
# iniciamos los subplots
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (30, 10))

# definimos una lista de colores. Cada color corresponderá a una gráfica
lista_colores = ["blue", "green", "red", "cyan", "magenta"]

# hemos creado una gráfica con varios subplots. Si queremos automatizar el proceso de relleno de cada uno de los plots
## podemos usar el método .flat. Lo que hace es aplanar los ejes para que queden en una única dimensión
## y luego los vamos rellenando. 
axes = axes.flat

# seleccionamos las columnas que queremos graficar
columnas_numeric = df.select_dtypes(include = np.number).drop('Price', axis=1)
columnas_numeric = columnas_numeric.columns

# iniciamos un for loop para no tener que escribir la misma línea de código muchas veces
for i, colum in enumerate(columnas_numeric): 
    sns.regplot(
        data = df,
        x = colum,
        y = 'Price',
        #color = lista_colores[i],
        line_kws = {"color": "black", "alpha": 0.7 }, 
        ax = axes[i])
    
    # establecemos el título de cada gráfica
    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")

    # establacemos el tamaño de la letras de los ejes
    axes[i].tick_params(labelsize = 20)

    # establecemos que no queremos que aparezca nada en el eje x
    axes[i].set_xlabel("")
    
# ajustamos el tamaño de cada subplot para que no se vean superpuestos. 
fig.tight_layout();

# %% [markdown]
# Basándonos en esta imagen, no poríamos decir, que ninguna variable sea homocedastica ya que la dispersión de puntos no es constante.

# %% [markdown]
# - Realizamos el test de levene para ver la homogeneidad analíticamente

# %%
# creamos un diccionario para almacenar los resultados de los test
resultados = {}

# seleccionamos solo las columnas numéricas y eliminamos la columna de precio
numericas_col = df.select_dtypes(include = np.number).drop("Price", axis = 1).columns

#iteremos por la lista de las columnas numéricas
for col in numericas_col:
    # calculamos el p-valor de test
    statistic, p_val = levene(df[col], df.Price, center='median')
    # lo almacenamos en el charges
    resultados[col] = p_val

# %%
resultados
# Out:
# {'Levy': 0.0,
#  'Prod. year': 0.0,
#  'Mileage': 0.0,
#  'Cylinders': 0.0,
#  'Airbags': 0.0}

# %% [markdown]
# p-value < 0.05, por lo tanto, podemos decir que las variables analizadas **no** cumplen la asunción de homocedasticidad.

# %% [markdown]
# ### <font color=violet> Independencia de las variables

# %% [markdown]
# - Para ver la independencia visualmente realizamos el heatmap

# %%
plt.figure()
sns.heatmap(df.corr(), annot=True, cmap = 'plasma')
plt.show()

# %%
# Creamos un dataframe todo de unos de la misma forma que nuestra matriz de correlación
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))
mask
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [False,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True],
#        [False, False, False, False,  True,  True],
#        [False, False, False, False, False,  True]])

# %%
sns.heatmap(df.corr(),
            cmap = "plasma", 
            mask = mask, # incorporamos la máscara en nuestro plot
            annot = True);

# %% [markdown]
# - Realizamos el chi-cuadrado para ver nuestra independencia analiticamente

# %%
predictoras = df.columns.drop("Price")
predictoras
# Out:
# Index(['Levy', 'Manufacturer', 'Prod. year', 'Category', 'Leather interior',
#        'Fuel type', 'Engine volume', 'Mileage', 'Cylinders', 'Gear box type',
#        'Drive wheels', 'Doors', 'Color', 'Airbags'],
#       dtype='object')

# %%
from itertools import combinations
 
 
# size of combination is set to 3
combinaciones = list(combinations(predictoras, 2))
print(combinaciones)
# Out:
# [('Levy', 'Manufacturer'), ('Levy', 'Prod. year'), ('Levy', 'Category'), ('Levy', 'Leather interior'), ('Levy', 'Fuel type'), ('Levy', 'Engine volume'), ('Levy', 'Mileage'), ('Levy', 'Cylinders'), ('Levy', 'Gear box type'), ('Levy', 'Drive wheels'), ('Levy', 'Doors'), ('Levy', 'Color'), ('Levy', 'Airbags'), ('Manufacturer', 'Prod. year'), ('Manufacturer', 'Category'), ('Manufacturer', 'Leather interior'), ('Manufacturer', 'Fuel type'), ('Manufacturer', 'Engine volume'), ('Manufacturer', 'Mileage'), ('Manufacturer', 'Cylinders'), ('Manufacturer', 'Gear box type'), ('Manufacturer', 'Drive wheels'), ('Manufacturer', 'Doors'), ('Manufacturer', 'Color'), ('Manufacturer', 'Airbags'), ('Prod. year', 'Category'), ('Prod. year', 'Leather interior'), ('Prod. year', 'Fuel type'), ('Prod. year', 'Engine volume'), ('Prod. year', 'Mileage'), ('Prod. year', 'Cylinders'), ('Prod. year', 'Gear box type'), ('Prod. year', 'Drive wheels'), ('Prod. year', 'Doors'), ('Prod. year', 'Color'), ('Prod. year', 'Airbags'), ('Category', 'Leather interior'), ('Category', 'Fuel type'), ('Category', 'Engine volume'), ('Category', 'Mileage'), ('Category', 'Cylinders'), ('Category', 'Gear box type'), ('Category', 'Drive wheels'), ('Category', 'Doors'), ('Category', 'Color'), ('Category', 'Airbags'), ('Leather interior', 'Fuel type'), ('Leather interior', 'Engine volume'), ('Leather interior', 'Mileage'), ('Leather interior', 'Cylinders'), ('Leather interior', 'Gear box type'), ('Leather interior', 'Drive wheels'), ('Leather interior', 'Doors'), ('Leather interior', 'Color'), ('Leather interior', 'Airbags'), ('Fuel type', 'Engine volume'), ('Fuel type', 'Mileage'), ('Fuel type', 'Cylinders'), ('Fuel type', 'Gear box type'), ('Fuel type', 'Drive wheels'), ('Fuel type', 'Doors'), ('Fuel type', 'Color'), ('Fuel type', 'Airbags'), ('Engine volume', 'Mileage'), ('Engine volume', 'Cylinders'), ('Engine volume', 'Gear box type'), ('Engine volume', 'Drive wheels'), ('Engine volume', 'Doors'), ('Engine volume', 'Color'), ('Engine volume', 'Airbags'), ('Mileage', 'Cylinders'), ('Mileage', 'Gear box type'), ('Mileage', 'Drive wheels'), ('Mileage', 'Doors'), ('Mileage', 'Color'), ('Mileage', 'Airbags'), ('Cylinders', 'Gear box type'), ('Cylinders', 'Drive wheels'), ('Cylinders', 'Doors'), ('Cylinders', 'Color'), ('Cylinders', 'Airbags'), ('Gear box type', 'Drive wheels'), ('Gear box type', 'Doors'), ('Gear box type', 'Color'), ('Gear box type', 'Airbags'), ('Drive wheels', 'Doors'), ('Drive wheels', 'Color'), ('Drive wheels', 'Airbags'), ('Doors', 'Color'), ('Doors', 'Airbags'), ('Color', 'Airbags')]

# %%
for i in combinaciones:
    crosstab, test_results, expected = rp.crosstab(df[i[0]], df[i[1]],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
    print(f"INDEPENDENCIA ENTRE {i[0], i[1]} \n", test_results)
    print("........................")
# Out:
# INDEPENDENCIA ENTRE ('Levy', 'Manufacturer')
#                      Chi-square test     results
# 0  Pearson Chi-square ( 24909.0) =   77501.6994
# 1                        p-value =       0.0000
# 2                     Cramer's V =       0.3164
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Prod. year')
#                     Chi-square test      results
# 0  Pearson Chi-square ( 8303.0) =   133823.0613
# 1                       p-value =        0.0000
# 2                    Cramer's V =        0.7201
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Category')
#                     Chi-square test     results
# 0  Pearson Chi-square ( 4370.0) =   18687.9235
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.3709
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Leather interior')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 437.0) =   3504.8682
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.5080
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Fuel type')
#                     Chi-square test    results
# 0  Pearson Chi-square ( 2622.0) =   12591.305
# 1                       p-value =       0.000
# 2                    Cramer's V =       0.393
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Engine volume')
#                      Chi-square test      results
# 0  Pearson Chi-square ( 43700.0) =   341013.6221
# 1                        p-value =        0.0000
# 2                     Cramer's V =        0.5010
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Mileage')
#                        Chi-square test       results
# 0  Pearson Chi-square ( 2925278.0) =   3.700875e+06
# 1                          p-value =   0.000000e+00
# 2                       Cramer's V =   7.896000e-01
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Cylinders')
#                     Chi-square test     results
# 0  Pearson Chi-square ( 4807.0) =   19154.0496
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.3580
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Gear box type')
#                     Chi-square test    results
# 0  Pearson Chi-square ( 1311.0) =   6205.2722
# 1                       p-value =      0.0000
# 2                    Cramer's V =      0.3902
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Drive wheels')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 874.0) =   5456.2011
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.4481
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Doors')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 874.0) =   1554.2203
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.2392
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Color')
#                     Chi-square test     results
# 0  Pearson Chi-square ( 6555.0) =   10031.7128
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.2219
# ........................
# INDEPENDENCIA ENTRE ('Levy', 'Airbags')
#                     Chi-square test     results
# 0  Pearson Chi-square ( 6992.0) =   14602.2579
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.2592
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Prod. year')
#                     Chi-square test    results
# 0  Pearson Chi-square ( 1083.0) =   6733.8640
# 1                       p-value =      0.0000
# 2                    Cramer's V =      0.1615
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Category')
#                    Chi-square test     results
# 0  Pearson Chi-square ( 570.0) =   11203.7492
# 1                      p-value =       0.0000
# 2                   Cramer's V =       0.2872
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Leather interior')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 57.0) =   3078.4583
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.4761
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Fuel type')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 342.0) =   8817.4772
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.3289
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Engine volume')
#                     Chi-square test     results
# 0  Pearson Chi-square ( 5700.0) =   88015.5472
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.3372
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Mileage')
#                       Chi-square test      results
# 0  Pearson Chi-square ( 381558.0) =   330410.1387
# 1                         p-value =        1.0000
# 2                      Cramer's V =        0.6532
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Cylinders')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 627.0) =   8669.4021
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.2409
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Gear box type')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 171.0) =   6773.0472
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.4077
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Drive wheels')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 114.0) =   9998.7030
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.6067
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Doors')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 114.0) =   1547.9840
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.2387
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Color')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 855.0) =   2654.5864
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1141
# ........................
# INDEPENDENCIA ENTRE ('Manufacturer', 'Airbags')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 912.0) =   7907.1383
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1907
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Category')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 190.0) =   1966.7913
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1203
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Leather interior')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 19.0) =   1284.0591
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.3075
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Fuel type')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 114.0) =   2974.1649
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1910
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Engine volume')
#                     Chi-square test    results
# 0  Pearson Chi-square ( 1900.0) =   8303.2552
# 1                       p-value =      0.0000
# 2                    Cramer's V =      0.1794
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Mileage')
#                       Chi-square test      results
# 0  Pearson Chi-square ( 127186.0) =   127048.3620
# 1                         p-value =        0.6071
# 2                      Cramer's V =        0.7016
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Cylinders')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 209.0) =   1058.2154
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0842
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Gear box type')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 57.0) =   2473.6184
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.2464
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Drive wheels')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 38.0) =   1366.4667
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.2243
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Doors')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 38.0) =   368.4062
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.1164
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Color')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 285.0) =   1298.2646
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0798
# ........................
# INDEPENDENCIA ENTRE ('Prod. year', 'Airbags')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 304.0) =   2992.2162
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1173
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Leather interior')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 10.0) =   1934.2504
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.3773
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Fuel type')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 60.0) =   5996.3006
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.2712
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Engine volume')
#                     Chi-square test     results
# 0  Pearson Chi-square ( 1000.0) =   19407.6478
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.3780
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Mileage')
#                      Chi-square test     results
# 0  Pearson Chi-square ( 66940.0) =   53354.2542
# 1                        p-value =       1.0000
# 2                     Cramer's V =       0.6267
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Cylinders')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 110.0) =   1523.6971
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1059
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Gear box type')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 30.0) =   5321.7396
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.3614
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Drive wheels')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 20.0) =   4846.9847
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.4224
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Doors')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 20.0) =   5580.9264
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.4532
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Color')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 150.0) =   1593.3452
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1083
# ........................
# INDEPENDENCIA ENTRE ('Category', 'Airbags')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 160.0) =   3595.4305
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1627
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Fuel type')
#                  Chi-square test   results
# 0  Pearson Chi-square ( 6.0) =   656.0850
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.2198
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Engine volume')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 100.0) =   2687.5810
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.4448
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Mileage')
#                     Chi-square test    results
# 0  Pearson Chi-square ( 6694.0) =   6002.4348
# 1                       p-value =      1.0000
# 2                    Cramer's V =      0.6647
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Cylinders')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 11.0) =   528.2220
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.1972
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Gear box type')
#                  Chi-square test    results
# 0  Pearson Chi-square ( 3.0) =   1952.8770
# 1                    p-value =      0.0000
# 2                 Cramer's V =      0.3792
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Drive wheels')
#                  Chi-square test  results
# 0  Pearson Chi-square ( 2.0) =   31.6122
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0482
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Doors')
#                  Chi-square test  results
# 0  Pearson Chi-square ( 2.0) =   75.1693
# 1                    p-value =    0.0000
# 2                 Cramer's V =    0.0744
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Color')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 15.0) =   350.9596
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.1607
# ........................
# INDEPENDENCIA ENTRE ('Leather interior', 'Airbags')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 16.0) =   2867.4684
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.4594
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Engine volume')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 600.0) =   9573.9661
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.3427
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Mileage')
#                      Chi-square test     results
# 0  Pearson Chi-square ( 40164.0) =   31379.8294
# 1                        p-value =       1.0000
# 2                     Cramer's V =       0.6205
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Cylinders')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 66.0) =   694.9362
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.0923
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Gear box type')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 18.0) =   2377.9312
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.2416
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Drive wheels')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 12.0) =   816.7291
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.1734
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Doors')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 12.0) =   142.0144
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.0723
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Color')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 90.0) =   2651.3241
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.1804
# ........................
# INDEPENDENCIA ENTRE ('Fuel type', 'Airbags')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 96.0) =   3257.6042
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.1999
# ........................
# INDEPENDENCIA ENTRE ('Engine volume', 'Mileage')
#                       Chi-square test      results
# 0  Pearson Chi-square ( 669400.0) =   532978.9204
# 1                         p-value =        1.0000
# 2                      Cramer's V =        0.6264
# ........................
# INDEPENDENCIA ENTRE ('Engine volume', 'Cylinders')
#                     Chi-square test     results
# 0  Pearson Chi-square ( 1100.0) =   31768.5462
# 1                       p-value =       0.0000
# 2                    Cramer's V =       0.4611
# ........................
# INDEPENDENCIA ENTRE ('Engine volume', 'Gear box type')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 300.0) =   7737.7532
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.4357
# ........................
# INDEPENDENCIA ENTRE ('Engine volume', 'Drive wheels')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 200.0) =   8203.5033
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.5495
# ........................
# INDEPENDENCIA ENTRE ('Engine volume', 'Doors')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 200.0) =   1812.7524
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.2583
# ........................
# INDEPENDENCIA ENTRE ('Engine volume', 'Color')
#                     Chi-square test    results
# 0  Pearson Chi-square ( 1500.0) =   3091.4459
# 1                       p-value =      0.0000
# 2                    Cramer's V =      0.1232
# ........................
# INDEPENDENCIA ENTRE ('Engine volume', 'Airbags')
#                     Chi-square test    results
# 0  Pearson Chi-square ( 1600.0) =   9065.7542
# 1                       p-value =      0.0000
# 2                    Cramer's V =      0.2042
# ........................
# INDEPENDENCIA ENTRE ('Mileage', 'Cylinders')
#                      Chi-square test     results
# 0  Pearson Chi-square ( 73634.0) =   46552.5424
# 1                        p-value =       1.0000
# 2                     Cramer's V =       0.5582
# ........................
# INDEPENDENCIA ENTRE ('Mileage', 'Gear box type')
#                      Chi-square test     results
# 0  Pearson Chi-square ( 20082.0) =   13279.5424
# 1                        p-value =       1.0000
# 2                     Cramer's V =       0.5708
# ........................
# INDEPENDENCIA ENTRE ('Mileage', 'Drive wheels')
#                      Chi-square test     results
# 0  Pearson Chi-square ( 13388.0) =   11419.4087
# 1                        p-value =       1.0000
# 2                     Cramer's V =       0.6483
# ........................
# INDEPENDENCIA ENTRE ('Mileage', 'Doors')
#                      Chi-square test    results
# 0  Pearson Chi-square ( 13388.0) =   6117.3990
# 1                        p-value =      1.0000
# 2                     Cramer's V =      0.4745
# ........................
# INDEPENDENCIA ENTRE ('Mileage', 'Color')
#                       Chi-square test     results
# 0  Pearson Chi-square ( 100410.0) =   88310.9180
# 1                         p-value =       1.0000
# 2                      Cramer's V =       0.6583
# ........................
# INDEPENDENCIA ENTRE ('Mileage', 'Airbags')
#                       Chi-square test     results
# 0  Pearson Chi-square ( 107104.0) =   67266.5789
# 1                         p-value =       1.0000
# 2                      Cramer's V =       0.5563
# ........................
# INDEPENDENCIA ENTRE ('Cylinders', 'Gear box type')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 33.0) =   1421.3047
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.1868
# ........................
# INDEPENDENCIA ENTRE ('Cylinders', 'Drive wheels')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 22.0) =   5166.9025
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.4361
# ........................
# INDEPENDENCIA ENTRE ('Cylinders', 'Doors')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 22.0) =   191.1243
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.0839
# ........................
# INDEPENDENCIA ENTRE ('Cylinders', 'Color')
#                    Chi-square test   results
# 0  Pearson Chi-square ( 165.0) =   653.3816
# 1                      p-value =     0.0000
# 2                   Cramer's V =     0.0661
# ........................
# INDEPENDENCIA ENTRE ('Cylinders', 'Airbags')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 176.0) =   3001.7230
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.1417
# ........................
# INDEPENDENCIA ENTRE ('Gear box type', 'Drive wheels')
#                  Chi-square test    results
# 0  Pearson Chi-square ( 6.0) =   1870.7609
# 1                    p-value =      0.0000
# 2                 Cramer's V =      0.2624
# ........................
# INDEPENDENCIA ENTRE ('Gear box type', 'Doors')
#                  Chi-square test    results
# 0  Pearson Chi-square ( 6.0) =   1114.2526
# 1                    p-value =      0.0000
# 2                 Cramer's V =      0.2025
# ........................
# INDEPENDENCIA ENTRE ('Gear box type', 'Color')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 45.0) =   468.9437
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.1073
# ........................
# INDEPENDENCIA ENTRE ('Gear box type', 'Airbags')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 48.0) =   4256.9366
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.3232
# ........................
# INDEPENDENCIA ENTRE ('Drive wheels', 'Doors')
#                  Chi-square test   results
# 0  Pearson Chi-square ( 4.0) =   924.5965
# 1                    p-value =     0.0000
# 2                 Cramer's V =     0.1845
# ........................
# INDEPENDENCIA ENTRE ('Drive wheels', 'Color')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 30.0) =   338.4536
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.1116
# ........................
# INDEPENDENCIA ENTRE ('Drive wheels', 'Airbags')
#                   Chi-square test    results
# 0  Pearson Chi-square ( 32.0) =   1921.0925
# 1                     p-value =      0.0000
# 2                  Cramer's V =      0.2659
# ........................
# INDEPENDENCIA ENTRE ('Doors', 'Color')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 30.0) =   135.0395
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.0705
# ........................
# INDEPENDENCIA ENTRE ('Doors', 'Airbags')
#                   Chi-square test   results
# 0  Pearson Chi-square ( 32.0) =   353.1705
# 1                     p-value =     0.0000
# 2                  Cramer's V =     0.1140
# ........................
# INDEPENDENCIA ENTRE ('Color', 'Airbags')
#                    Chi-square test    results
# 0  Pearson Chi-square ( 240.0) =   1262.5184
# 1                      p-value =      0.0000
# 2                   Cramer's V =      0.0787
# ........................

# %% [markdown]
# El p-valor entre kilometros y: cilindros, tipos de caja de cambios, tracción de las ruedas, puertas, color y airbag es de 1, por lo tanto al ser > 0.05 no podemos rechazar H0, es decir, nuestras variables son independientes.
#
# El resto de P-valores es de 0 por lo tanto al ser < 0.05 podemos rechazar H0, es decir, nuestras variables son dependientes

# %% [markdown]
# Guardamos el dataset nuevamente porque hemos hecho modificaciones. En pickle para que nos conserve el tipo de datos.

# %%
df.to_pickle('datos/cars_price2.pkl')

# %%
df.to_csv('datos/cars_price2.csv')
